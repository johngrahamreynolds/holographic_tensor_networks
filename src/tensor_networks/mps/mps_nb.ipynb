# %% [markdown]
# <a href="https://colab.research.google.com/github/johngrahamreynolds/holographic_tensor_networks/blob/7-implement-tensor-network-model-and-optimization-of-ising-1d-open-bc/src/tensor_networks/mps/mps_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/johngrahamreynolds/holographic_tensor_networks.git
# Out:
# Cloning into 'holographic_tensor_networks'...
# remote: Enumerating objects: 411, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 411 (delta 44), reused 55 (delta 34), pack-reused 334 (from 1)
# Receiving objects: 100% (411/411), 42.59 MiB | 37.79 MiB/s, done.
# Resolving deltas: 100% (167/167), done.

# %%
# must use % here instead of ! - !-prefaced commands run in their own subshell
# %cd holographic_tensor_networks/
# Out:
# /content/holographic_tensor_networks

# %%
# !git branch -a
# Out:
# * main
#   remotes/origin/10-refactor-repo-as-a-pyproject-to-ease-imports
#   remotes/origin/5-refactor-repo-into-research-format
#   remotes/origin/7-implement-tensor-network-model-and-optimization-of-ising-1d-open-bc
#   remotes/origin/8-build-in-quantum-backends-for-execution-of-quantum-circuits-on-qpus
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/main

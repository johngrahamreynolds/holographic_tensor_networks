# %% [markdown]
# # MPS Example Training
#
# This notebook demonstrates training an MPS tensor network to represent the one-dimensional Ising model using a CUDA-enabled GPU.
#
# **For end users:** This notebook provides a simple way to run examples. If running this inside a serverless compute instance like Google Colab or Databricks, the first cell below should be executed to pull the project code into the virtual machine. Run the setup cell below and then execute the example cells.

# %% [markdown]
# ## Setup
#
# Run this cell to install the package and its dependencies. This will clone the repository from GitHub and install it in editable mode.

# %%
""" 
NOTE: uncomment and run this cell only if using a serverless compute instance like Google Colab

Downloads the project repo, installs the package, and hops into src directory of the project for access to modules

"""

# !git clone https://github.com/johngrahamreynolds/holographic_tensor_networks.git
# %cd holographic_tensor_networks
# %pip install -e . --quiet
# %cd src

# %%
# This cell can be run directly in the project if running locally

from tensor_networks.mps import MPS
from tensor_networks.mps.train_mps import train_mps

mps = MPS(num_sites=5, bond_dim=3, physical_dim=2)
train_mps(mps, dataset_name="ising_1d_open")
